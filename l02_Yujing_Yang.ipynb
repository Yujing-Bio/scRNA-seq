# %% [markdown]
# ### From reads to matrix  --Processing of scRNA seq generated by batch seq
#     recording my thoughts and test

# %% [markdown]
# #### barcoding:
# **1)** sci-RNA-seq3: UMI-attach.py
# **2)** Guttman lab: Java
# **3)** Kallisto : white list
